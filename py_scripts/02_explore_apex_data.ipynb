# %% [markdown]
# # APEX Logistics Operations
# ###  Exploritory Analysis

# %%
import pandas as pd

# Load dataset genrated by 01_data_generator
df = pd.read_csv('apex_logistics_raw.csv')

# %%
# Exploring apex_logistics_raw table
print('Dateframe Info')
print(df.info()) # Data types and total non-null rows
print("\n")

print('First 10 Rows')
print(df.head(10)) # Check first 10 rows to quckly view data
print("\n")

print('Missing Values')
print(df.isnull().sum()) # Number of NULL values within the data
print("\n")

print('Summary Statistics')
print(df.describe()) # min, max, and average distances and delays
print('\n')

print('Damaged Packages Null Counter')
print(df['Damaged_Flag'].value_counts(dropna=False)) # Looking to ensure intentional NULL values were created
print('\n')

print('Weather Conditions')
print(df['WeatherCondition'].value_counts())
# Out:
# Dateframe Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   OrderID               12000 non-null  object
#  1   Region                12000 non-null  object
#  2   VehicleType           12000 non-null  object
#  3   WeatherCondition      12000 non-null  object
#  4   Distance_Miles        12000 non-null  int64
#  5   OrderDate             12000 non-null  object
#  6   Damaged_Flag          11379 non-null  object
#  7   ExpectedDeliveryDate  12000 non-null  object
#  8   ActualDeliveryDate    11760 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 843.9+ KB
# None
#
#
# First 10 Rows
#      OrderID Region   VehicleType WeatherCondition  Distance_Miles  \
# 0  ORD-00001   East     Box Truck             Rain             342
# 1  ORD-00002   West           Van            Clear             612
# 2  ORD-00003  North  Semi-Trailer            Clear             175
# 3  ORD-00004   East     Box Truck             Rain             170
# 4  ORD-00005   East           Van             Snow              15
# 5  ORD-00006   West  Semi-Trailer            Clear             214
# 6  ORD-00007  North     Box Truck            Clear             541
# 7  ORD-00008  North           Van              Fog            1133
# 8  ORD-00009   East     Box Truck            Clear              54
# 9  ORD-00010  South           Van            Clear             466
#
#     OrderDate Damaged_Flag ExpectedDeliveryDate ActualDeliveryDate
# 0  2023-03-07           No           2023-03-09         2023-03-09
# 1  2022-09-04           No           2022-09-07         2022-09-07
# 2  2023-01-06           No           2023-01-07         2023-01-07
# 3  2022-10-03           No           2022-10-04         2022-10-04
# 4  2022-07-26           No           2022-07-27         2022-07-30
# 5  2023-02-26           No           2023-02-27         2023-03-01
# 6  2022-05-31           No           2022-06-02         2022-06-02
# 7  2022-11-16          NaN           2022-11-20         2022-11-23
# 8  2022-09-24           No           2022-09-25         2022-09-26
# 9  2023-05-09          Yes           2023-05-11         2023-05-11
#
#
# Missing Values
# OrderID                   0
# Region                    0
# VehicleType               0
# WeatherCondition          0
# Distance_Miles            0
# OrderDate                 0
# Damaged_Flag            621
# ExpectedDeliveryDate      0
# ActualDeliveryDate      240
# dtype: int64
#
#
# Summary Statistics
#        Distance_Miles
# count    12000.000000
# mean       750.819500
# std        431.540262
# min         10.000000
# 25%        374.000000
# 50%        751.000000
# 75%       1123.250000
# max       1499.000000
#
#
# Damaged Packages Null Counter
# Damaged_Flag
# No     10832
# NaN      621
# Yes      547
# Name: count, dtype: int64
#
#
# Weather Conditions
# WeatherCondition
# Clear    7133
# Rain     2491
# Fog      1201
# Snow     1175
# Name: count, dtype: int64
